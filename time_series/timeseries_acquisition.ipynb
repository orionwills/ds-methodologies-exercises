# %%
import pandas as pd
import numpy as np
from datetime import datetime
import itertools

# JSON API
import requests
import json

# data visualization
import matplotlib
import seaborn as sns
import statsmodels.api as sm

# %matplotlib inline

# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
def get_response(url):
    return requests.get(url)

# %%
url = 'https://python.zach.lol/api/v1/'

# %%
get_response(url)
# Out:
# <Response [200]>

# %%
resources = ['items', 'stores', 'sales']

# %%
df = pd.DataFrame()

# %%
response0 = requests.get(url + resources[0])
response1 = requests.get(url + resources[1])
response2 = requests.get(url + resources[2])

data0 = response0.json()
data1 = response1.json()
data2 = response2.json()

for i in (data0, data1, data2):
    print(i['payload'].keys())
# Out:
# dict_keys(['items', 'max_page', 'next_page', 'page', 'previous_page'])
# dict_keys(['max_page', 'next_page', 'page', 'previous_page', 'stores'])
# dict_keys(['max_page', 'next_page', 'page', 'previous_page', 'sales'])

# %%
def get_any(resource):
    base_url = 'https://python.zach.lol'
    df = pd.DataFrame()
    url = 'https://python.zach.lol/api/v1/' + resource
    r = requests.get('https://python.zach.lol/api/v1/' + resource)
    data = r.json()
    
    if data['payload']['max_page'] == 1:
        df = pd.concat([df, pd.DataFrame(data['payload'][resource])])
    else:
        df = pd.concat([df, pd.DataFrame(data['payload'][resource])])
        r = requests.get(base_url + data['payload']['next_page'])
        data = r.json()

        while data['payload']['page'] <= data['payload']['max_page']:
            df = pd.concat([df, pd.DataFrame(data['payload'][resource])])
            if data['payload']['page'] == data['payload']['max_page']:
                break
            r = requests.get(base_url + data['payload']['next_page'])
            data = r.json()
    df.to_csv(resource + '.csv')
    return df.reset_index(drop=True)

# %%
def get_sales(csv):
    base_url = 'https://python.zach.lol'
    
    df = pd.DataFrame()
    url = 'https://python.zach.lol/api/v1/sales'
    r = requests.get('https://python.zach.lol/api/v1/sales')
    data = r.json()
    
    df = pd.concat([df, pd.DataFrame(data['payload']['sales'])])

    r = requests.get(base_url + data['payload']['next_page'])
    data = r.json()
    
    while data['payload']['page'] <= data['payload']['max_page']:
        
        df = pd.concat([df, pd.DataFrame(data['payload']['sales'])])
        
        if data['payload']['page'] == data['payload']['max_page']:
            break
            
        r = requests.get(base_url + data['payload']['next_page'])
        data = r.json()
    df.to_csv(csv)
    return df.reset_index(drop=True)

# %%
def get_stores(csv):
    base_url = 'https://python.zach.lol'
    
    df = pd.DataFrame()
    url = 'https://python.zach.lol/api/v1/stores'
    r = requests.get('https://python.zach.lol/api/v1/stores')
    data = r.json()
    
    df = pd.concat([df, pd.DataFrame(data['payload']['stores'])])
    df.to_csv(csv)
    return df.reset_index(drop=True)

# %%
def get_items(csv):
    base_url = 'https://python.zach.lol'
    
    df = pd.DataFrame()
    url = 'https://python.zach.lol/api/v1/items'
    r = requests.get('https://python.zach.lol/api/v1/items')
    data = r.json()
    
    df = pd.concat([df, pd.DataFrame(data['payload']['items'])])

    r = requests.get(base_url + data['payload']['next_page'])
    data = r.json()
    
    while data['payload']['page'] <= data['payload']['max_page']:
        
        df = pd.concat([df, pd.DataFrame(data['payload']['items'])])
        
        if data['payload']['page'] == data['payload']['max_page']:
            break
            
        r = requests.get(base_url + data['payload']['next_page'])
        data = r.json()
    df.to_csv(csv)
    return df.reset_index(drop=True)

# %%
def merge_dfs(df1, df2, how, left, right):
    return pd.merge(df1, df2, how=how, left_on=left, right_on=right)

# %%
items = pd.read_csv('~/python/Methodologies/time_series/items.csv', index_col=0)
stores = pd.read_csv('~/python/Methodologies/time_series/stores.csv', index_col=0)
sales = pd.read_csv('~/python/Methodologies/time_series/sales.csv', index_col=0)

# %%
sales.shape
# Out:
# (913000, 5)

# %%
df = merge_dfs(items, sales, 'left', 'item_id', 'item')
df.shape
# Out:
# (913000, 11)

# %%
df.head()
# Out:
#   item_brand  item_id                       item_name  item_price  \
# 0   Riceland        1  Riceland American Jazmine Rice        0.84
# 1   Riceland        1  Riceland American Jazmine Rice        0.84
# 2   Riceland        1  Riceland American Jazmine Rice        0.84
# 3   Riceland        1  Riceland American Jazmine Rice        0.84
# 4   Riceland        1  Riceland American Jazmine Rice        0.84
#
#     item_upc12   item_upc14  item  sale_amount                      sale_date  \
# 0  35200264013  35200264013     1         13.0  Tue, 01 Jan 2013 00:00:00 GMT
# 1  35200264013  35200264013     1         11.0  Wed, 02 Jan 2013 00:00:00 GMT
# 2  35200264013  35200264013     1         14.0  Thu, 03 Jan 2013 00:00:00 GMT
# 3  35200264013  35200264013     1         13.0  Fri, 04 Jan 2013 00:00:00 GMT
# 4  35200264013  35200264013     1         10.0  Sat, 05 Jan 2013 00:00:00 GMT
#
#    sale_id  store
# 0        1      1
# 1        2      1
# 2        3      1
# 3        4      1
# 4        5      1

# %%
df = merge_dfs(df, stores, 'left', 'store', 'store_id')
df.shape
# Out:
# (913000, 16)

# %%
def clean_up_columns():
    return df.drop(columns=(['store', 'item']))

# %%
df = clean_up_columns()

# %%
df.columns
# Out:
# Index(['item_brand', 'item_id', 'item_name', 'item_price', 'item_upc12',
#        'item_upc14', 'sale_amount', 'sale_date', 'sale_id', 'store_address',
#        'store_city', 'store_id', 'store_state', 'store_zipcode'],
#       dtype='object')

# %%
df
# Out:
#        item_brand  item_id                                          item_name  \
# 0        Riceland        1                     Riceland American Jazmine Rice
# 1        Riceland        1                     Riceland American Jazmine Rice
# 2        Riceland        1                     Riceland American Jazmine Rice
# 3        Riceland        1                     Riceland American Jazmine Rice
# 4        Riceland        1                     Riceland American Jazmine Rice
# 5        Riceland        1                     Riceland American Jazmine Rice
# 6        Riceland        1                     Riceland American Jazmine Rice
# 7        Riceland        1                     Riceland American Jazmine Rice
# 8        Riceland        1                     Riceland American Jazmine Rice
# 9        Riceland        1                     Riceland American Jazmine Rice
# 10       Riceland        1                     Riceland American Jazmine Rice
# 11       Riceland        1                     Riceland American Jazmine Rice
# 12       Riceland        1                     Riceland American Jazmine Rice
# 13       Riceland        1                     Riceland American Jazmine Rice
# 14       Riceland        1                     Riceland American Jazmine Rice
# 15       Riceland        1                     Riceland American Jazmine Rice
# 16       Riceland        1                     Riceland American Jazmine Rice
# 17       Riceland        1                     Riceland American Jazmine Rice
# 18       Riceland        1                     Riceland American Jazmine Rice
# 19       Riceland        1                     Riceland American Jazmine Rice
# 20       Riceland        1                     Riceland American Jazmine Rice
# 21       Riceland        1                     Riceland American Jazmine Rice
# 22       Riceland        1                     Riceland American Jazmine Rice
# 23       Riceland        1                     Riceland American Jazmine Rice
# 24       Riceland        1                     Riceland American Jazmine Rice
# 25       Riceland        1                     Riceland American Jazmine Rice
# 26       Riceland        1                     Riceland American Jazmine Rice
# 27       Riceland        1                     Riceland American Jazmine Rice
# 28       Riceland        1                     Riceland American Jazmine Rice
# 29       Riceland        1                     Riceland American Jazmine Rice
# ...           ...      ...                                                ...
# 912970     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912971     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912972     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912973     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912974     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912975     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912976     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912977     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912978     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912979     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912980     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912981     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912982     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912983     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912984     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912985     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912986     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912987     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912988     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912989     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912990     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912991     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912992     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912993     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912994     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912995     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912996     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912997     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912998     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
# 912999     Choice       50  Choice Organic Teas Black Tea Classic Black - ...
#
#         item_price   item_upc12   item_upc14  sale_amount  \
# 0             0.84  35200264013  35200264013         13.0
# 1             0.84  35200264013  35200264013         11.0
# 2             0.84  35200264013  35200264013         14.0
# 3             0.84  35200264013  35200264013         13.0
# 4             0.84  35200264013  35200264013         10.0
# 5             0.84  35200264013  35200264013         12.0
# 6             0.84  35200264013  35200264013         10.0
# 7             0.84  35200264013  35200264013          9.0
# 8             0.84  35200264013  35200264013         12.0
# 9             0.84  35200264013  35200264013          9.0
# 10            0.84  35200264013  35200264013          9.0
# 11            0.84  35200264013  35200264013          7.0
# 12            0.84  35200264013  35200264013         10.0
# 13            0.84  35200264013  35200264013         12.0
# 14            0.84  35200264013  35200264013          5.0
# 15            0.84  35200264013  35200264013          7.0
# 16            0.84  35200264013  35200264013         16.0
# 17            0.84  35200264013  35200264013          7.0
# 18            0.84  35200264013  35200264013         18.0
# 19            0.84  35200264013  35200264013         15.0
# 20            0.84  35200264013  35200264013          8.0
# 21            0.84  35200264013  35200264013          7.0
# 22            0.84  35200264013  35200264013          9.0
# 23            0.84  35200264013  35200264013          8.0
# 24            0.84  35200264013  35200264013         14.0
# 25            0.84  35200264013  35200264013         12.0
# 26            0.84  35200264013  35200264013         12.0
# 27            0.84  35200264013  35200264013         11.0
# 28            0.84  35200264013  35200264013          6.0
# 29            0.84  35200264013  35200264013          9.0
# ...            ...          ...          ...          ...
# 912970        5.20  47445919221  47445919221         49.0
# 912971        5.20  47445919221  47445919221         75.0
# 912972        5.20  47445919221  47445919221         54.0
# 912973        5.20  47445919221  47445919221         68.0
# 912974        5.20  47445919221  47445919221         60.0
# 912975        5.20  47445919221  47445919221         66.0
# 912976        5.20  47445919221  47445919221         67.0
# 912977        5.20  47445919221  47445919221         69.0
# 912978        5.20  47445919221  47445919221         69.0
# 912979        5.20  47445919221  47445919221         54.0
# 912980        5.20  47445919221  47445919221         67.0
# 912981        5.20  47445919221  47445919221         67.0
# 912982        5.20  47445919221  47445919221         72.0
# 912983        5.20  47445919221  47445919221         72.0
# 912984        5.20  47445919221  47445919221         52.0
# 912985        5.20  47445919221  47445919221         86.0
# 912986        5.20  47445919221  47445919221         53.0
# 912987        5.20  47445919221  47445919221         54.0
# 912988        5.20  47445919221  47445919221         51.0
# 912989        5.20  47445919221  47445919221         63.0
# 912990        5.20  47445919221  47445919221         75.0
# 912991        5.20  47445919221  47445919221         70.0
# 912992        5.20  47445919221  47445919221         76.0
# 912993        5.20  47445919221  47445919221         51.0
# 912994        5.20  47445919221  47445919221         41.0
# 912995        5.20  47445919221  47445919221         63.0
# 912996        5.20  47445919221  47445919221         59.0
# 912997        5.20  47445919221  47445919221         74.0
# 912998        5.20  47445919221  47445919221         62.0
# 912999        5.20  47445919221  47445919221         82.0
#
#                             sale_date  sale_id           store_address  \
# 0       Tue, 01 Jan 2013 00:00:00 GMT        1  12125 Alamo Ranch Pkwy
# 1       Wed, 02 Jan 2013 00:00:00 GMT        2  12125 Alamo Ranch Pkwy
# 2       Thu, 03 Jan 2013 00:00:00 GMT        3  12125 Alamo Ranch Pkwy
# 3       Fri, 04 Jan 2013 00:00:00 GMT        4  12125 Alamo Ranch Pkwy
# 4       Sat, 05 Jan 2013 00:00:00 GMT        5  12125 Alamo Ranch Pkwy
# 5       Sun, 06 Jan 2013 00:00:00 GMT        6  12125 Alamo Ranch Pkwy
# 6       Mon, 07 Jan 2013 00:00:00 GMT        7  12125 Alamo Ranch Pkwy
# 7       Tue, 08 Jan 2013 00:00:00 GMT        8  12125 Alamo Ranch Pkwy
# 8       Wed, 09 Jan 2013 00:00:00 GMT        9  12125 Alamo Ranch Pkwy
# 9       Thu, 10 Jan 2013 00:00:00 GMT       10  12125 Alamo Ranch Pkwy
# 10      Fri, 11 Jan 2013 00:00:00 GMT       11  12125 Alamo Ranch Pkwy
# 11      Sat, 12 Jan 2013 00:00:00 GMT       12  12125 Alamo Ranch Pkwy
# 12      Sun, 13 Jan 2013 00:00:00 GMT       13  12125 Alamo Ranch Pkwy
# 13      Mon, 14 Jan 2013 00:00:00 GMT       14  12125 Alamo Ranch Pkwy
# 14      Tue, 15 Jan 2013 00:00:00 GMT       15  12125 Alamo Ranch Pkwy
# 15      Wed, 16 Jan 2013 00:00:00 GMT       16  12125 Alamo Ranch Pkwy
# 16      Thu, 17 Jan 2013 00:00:00 GMT       17  12125 Alamo Ranch Pkwy
# 17      Fri, 18 Jan 2013 00:00:00 GMT       18  12125 Alamo Ranch Pkwy
# 18      Sat, 19 Jan 2013 00:00:00 GMT       19  12125 Alamo Ranch Pkwy
# 19      Sun, 20 Jan 2013 00:00:00 GMT       20  12125 Alamo Ranch Pkwy
# 20      Mon, 21 Jan 2013 00:00:00 GMT       21  12125 Alamo Ranch Pkwy
# 21      Tue, 22 Jan 2013 00:00:00 GMT       22  12125 Alamo Ranch Pkwy
# 22      Wed, 23 Jan 2013 00:00:00 GMT       23  12125 Alamo Ranch Pkwy
# 23      Thu, 24 Jan 2013 00:00:00 GMT       24  12125 Alamo Ranch Pkwy
# 24      Fri, 25 Jan 2013 00:00:00 GMT       25  12125 Alamo Ranch Pkwy
# 25      Sat, 26 Jan 2013 00:00:00 GMT       26  12125 Alamo Ranch Pkwy
# 26      Sun, 27 Jan 2013 00:00:00 GMT       27  12125 Alamo Ranch Pkwy
# 27      Mon, 28 Jan 2013 00:00:00 GMT       28  12125 Alamo Ranch Pkwy
# 28      Tue, 29 Jan 2013 00:00:00 GMT       29  12125 Alamo Ranch Pkwy
# 29      Wed, 30 Jan 2013 00:00:00 GMT       30  12125 Alamo Ranch Pkwy
# ...                               ...      ...                     ...
# 912970  Sat, 02 Dec 2017 00:00:00 GMT   912971    8503 NW Military Hwy
# 912971  Sun, 03 Dec 2017 00:00:00 GMT   912972    8503 NW Military Hwy
# 912972  Mon, 04 Dec 2017 00:00:00 GMT   912973    8503 NW Military Hwy
# 912973  Tue, 05 Dec 2017 00:00:00 GMT   912974    8503 NW Military Hwy
# 912974  Wed, 06 Dec 2017 00:00:00 GMT   912975    8503 NW Military Hwy
# 912975  Thu, 07 Dec 2017 00:00:00 GMT   912976    8503 NW Military Hwy
# 912976  Fri, 08 Dec 2017 00:00:00 GMT   912977    8503 NW Military Hwy
# 912977  Sat, 09 Dec 2017 00:00:00 GMT   912978    8503 NW Military Hwy
# 912978  Sun, 10 Dec 2017 00:00:00 GMT   912979    8503 NW Military Hwy
# 912979  Mon, 11 Dec 2017 00:00:00 GMT   912980    8503 NW Military Hwy
# 912980  Tue, 12 Dec 2017 00:00:00 GMT   912981    8503 NW Military Hwy
# 912981  Wed, 13 Dec 2017 00:00:00 GMT   912982    8503 NW Military Hwy
# 912982  Thu, 14 Dec 2017 00:00:00 GMT   912983    8503 NW Military Hwy
# 912983  Fri, 15 Dec 2017 00:00:00 GMT   912984    8503 NW Military Hwy
# 912984  Sat, 16 Dec 2017 00:00:00 GMT   912985    8503 NW Military Hwy
# 912985  Sun, 17 Dec 2017 00:00:00 GMT   912986    8503 NW Military Hwy
# 912986  Mon, 18 Dec 2017 00:00:00 GMT   912987    8503 NW Military Hwy
# 912987  Tue, 19 Dec 2017 00:00:00 GMT   912988    8503 NW Military Hwy
# 912988  Wed, 20 Dec 2017 00:00:00 GMT   912989    8503 NW Military Hwy
# 912989  Thu, 21 Dec 2017 00:00:00 GMT   912990    8503 NW Military Hwy
# 912990  Fri, 22 Dec 2017 00:00:00 GMT   912991    8503 NW Military Hwy
# 912991  Sat, 23 Dec 2017 00:00:00 GMT   912992    8503 NW Military Hwy
# 912992  Sun, 24 Dec 2017 00:00:00 GMT   912993    8503 NW Military Hwy
# 912993  Mon, 25 Dec 2017 00:00:00 GMT   912994    8503 NW Military Hwy
# 912994  Tue, 26 Dec 2017 00:00:00 GMT   912995    8503 NW Military Hwy
# 912995  Wed, 27 Dec 2017 00:00:00 GMT   912996    8503 NW Military Hwy
# 912996  Thu, 28 Dec 2017 00:00:00 GMT   912997    8503 NW Military Hwy
# 912997  Fri, 29 Dec 2017 00:00:00 GMT   912998    8503 NW Military Hwy
# 912998  Sat, 30 Dec 2017 00:00:00 GMT   912999    8503 NW Military Hwy
# 912999  Sun, 31 Dec 2017 00:00:00 GMT   913000    8503 NW Military Hwy
#
#          store_city  store_id store_state  store_zipcode
# 0       San Antonio         1          TX          78253
# 1       San Antonio         1          TX          78253
# 2       San Antonio         1          TX          78253
# 3       San Antonio         1          TX          78253
# 4       San Antonio         1          TX          78253
# 5       San Antonio         1          TX          78253
# 6       San Antonio         1          TX          78253
# 7       San Antonio         1          TX          78253
# 8       San Antonio         1          TX          78253
# 9       San Antonio         1          TX          78253
# 10      San Antonio         1          TX          78253
# 11      San Antonio         1          TX          78253
# 12      San Antonio         1          TX          78253
# 13      San Antonio         1          TX          78253
# 14      San Antonio         1          TX          78253
# 15      San Antonio         1          TX          78253
# 16      San Antonio         1          TX          78253
# 17      San Antonio         1          TX          78253
# 18      San Antonio         1          TX          78253
# 19      San Antonio         1          TX          78253
# 20      San Antonio         1          TX          78253
# 21      San Antonio         1          TX          78253
# 22      San Antonio         1          TX          78253
# 23      San Antonio         1          TX          78253
# 24      San Antonio         1          TX          78253
# 25      San Antonio         1          TX          78253
# 26      San Antonio         1          TX          78253
# 27      San Antonio         1          TX          78253
# 28      San Antonio         1          TX          78253
# 29      San Antonio         1          TX          78253
# ...             ...       ...         ...            ...
# 912970  San Antonio        10          TX          78231
# 912971  San Antonio        10          TX          78231
# 912972  San Antonio        10          TX          78231
# 912973  San Antonio        10          TX          78231
# 912974  San Antonio        10          TX          78231
# 912975  San Antonio        10          TX          78231
# 912976  San Antonio        10          TX          78231
# 912977  San Antonio        10          TX          78231
# 912978  San Antonio        10          TX          78231
# 912979  San Antonio        10          TX          78231
# 912980  San Antonio        10          TX          78231
# 912981  San Antonio        10          TX          78231
# 912982  San Antonio        10          TX          78231
# 912983  San Antonio        10          TX          78231
# 912984  San Antonio        10          TX          78231
# 912985  San Antonio        10          TX          78231
# 912986  San Antonio        10          TX          78231
# 912987  San Antonio        10          TX          78231
# 912988  San Antonio        10          TX          78231
# 912989  San Antonio        10          TX          78231
# 912990  San Antonio        10          TX          78231
# 912991  San Antonio        10          TX          78231
# 912992  San Antonio        10          TX          78231
# 912993  San Antonio        10          TX          78231
# 912994  San Antonio        10          TX          78231
# 912995  San Antonio        10          TX          78231
# 912996  San Antonio        10          TX          78231
# 912997  San Antonio        10          TX          78231
# 912998  San Antonio        10          TX          78231
# 912999  San Antonio        10          TX          78231
#
# [913000 rows x 14 columns]
